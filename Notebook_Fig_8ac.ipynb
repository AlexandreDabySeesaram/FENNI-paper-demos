# %%
#%% Libraries import
import sys  
sys.path.insert(1, '/Users/skardova/Dropbox/Lungs/HiDeNN_1D/hidenn_1d')

from HiDeNN_PDE import MeshNN, NeuROM, MeshNN_2D, MeshNN_1D
# Import pre-processing functions
import Bin.Pre_processing as pre
# Import torch librairies
import torch
import torch.nn as nn

# Import Training funcitons
from Bin.Training import Training_1D_FEM_LBFGS
#Import post processing libraries
import Post.Plots as Pplot
import time
import os
import torch._dynamo as dynamo
mps_device = torch.device("mps")
from importlib import reload  # Python 3.4+
import tomllib
import numpy as numpy
import argparse

# %%
# Load default configuration file (defines dimension, domain, boundary conditions, number of training iterations etc.)
Default_config_file = 'Configuration/config_1D.toml'

if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument('-cf',type=str, help = 'path to the desired configuration file', default=Default_config_file, action = 'store')
    
    args, unknown = parser.parse_known_args()

    inputs = vars(args)
    print(f"* Executing job in {args.cf}")

with open(args.cf, mode="rb") as f:
    config = tomllib.load(f)
# Out:
# * Executing job in Configuration/config_1D.toml

# %%
# Experiment setting: trapezoidal rule
# Tested variants: 6 mesh resolutions, 3 training sets, fixed and r-adaptive mesh

mesh_resolution = [10,21,41,80,160,324]
training_points = [10,20,30]

setting = ["fixed", "r-adaptive"]
config["solver"]["IntegralMethod"] = "Trapezoidal"

loss_u = numpy.zeros((len(setting),len(mesh_resolution), len(training_points)))
loss_grad = numpy.zeros((len(setting),len(mesh_resolution), len(training_points)))

for t in range(len(training_points)):
    config["training"]["Points_per_element"] = training_points[t]
    for se in range(len(setting)):
        if setting[se] == "fixed":
            config["solver"]["FrozenMesh"] = True
        elif setting[se] == "r-adaptive":
            config["solver"]["FrozenMesh"] = False

        for res in range(len(mesh_resolution)):

            config["interpolation"]["np"] = mesh_resolution[res]
            

            # Load parameters
            if config["interpolation"]["dimension"] == 1:
                Mat = pre.Material(             flag_lame = True,                               # If True should input lmbda and mu instead of E and nu
                                                coef1     = config["material"]["E"],            # Young Modulus
                                                coef2     = config["geometry"]["A"]             # Section area of the 1D bar
                                    )
            elif config["interpolation"]["dimension"] == 2:
                try:
                    Mat = pre.Material(         flag_lame = False,                              # If True should input lmbda and mu instead of E and nu
                                                coef1     = config["material"]["E"],            # Young Modulus
                                                coef2     = config["material"]["nu"]            # Poisson's ratio
                                    )
                except:
                    Mat = pre.Material(         flag_lame = True,                               # If True should input lmbda and mu instead of E and nu
                                                coef1     = config["material"]["lmbda"],        # First Lame's coef
                                                coef2     = config["material"]["mu"]            # Second Lame's coef
                                    )

            MaxElemSize = pre.ElementSize(
                                            dimension     = config["interpolation"]["dimension"],
                                            L             = config["geometry"]["L"],
                                            order         = config["interpolation"]["order"],
                                            np            = config["interpolation"]["np"],
                                        )

            Excluded = []

            Mesh_object = pre.Mesh( 
                                            config["geometry"]["Name"],                 # Create the mesh object
                                            MaxElemSize, 
                                            config["interpolation"]["order"], 
                                            config["interpolation"]["dimension"]
                                    )

            Mesh_object.AddBorders(config["Borders"]["Borders"])
            Mesh_object.AddBCs(                                                         # Include Boundary physical domains infos (BCs+volume)
                                            config["geometry"]["Volume_element"],
                                            Excluded,
                                            config["DirichletDictionryList"]
                                )                   

            Mesh_object.MeshGeo()                                                       # Mesh the .geo file if .msh does not exist
            Mesh_object.ReadMesh() 

            # Vtk file not necessary if not using reference element implementation
            if config["solver"]["IntegralMethod"] == "Gaussian_quad":
                Mesh_object.ExportMeshVtk1D()

            # Build the assembly weight matrix if needed
            if config["interpolation"]["dimension"] ==1 and config["solver"]["IntegralMethod"] == "Trapezoidal":
                Mesh_object.AssemblyMatrix()                                            

            if int(Mesh_object.dim) != int(Mesh_object.dimension):
                raise ValueError("The dimension of the provided geometry does not match the job dimension")

            if config["solver"]["TrainingStrategy"]=="Integral":
                match config["solver"]["IntegralMethod"]:                          
                    case "Gaussian_quad":
                        Model_FEM = MeshNN_1D(Mesh_object, config["interpolation"]["n_integr_points"])  
                    case "Trapezoidal":
                        Model_FEM = MeshNN(Mesh_object)

            if config["solver"]["TrainingStrategy"]=="Mixed":
                if config["solver"]["IntegralMethod"] == "Gaussian_quad":
                    Model_FEM = MeshNN_1D(Mesh_object, config["interpolation"]["n_integr_points"])
                    Model_test = MeshNN_1D(Mesh_object, config["interpolation"]["n_integr_points"])  
                    Model_test.Freeze_Mesh()

            # Default setting
            Model_FEM.Freeze_Mesh()
            Model_FEM.UnFreeze_FEM()

            if not config["solver"]["FrozenMesh"]:
                Model_FEM.UnFreeze_Mesh()    

            if config["solver"]["TrainingStrategy"]=="Mixed":
                Model_FEM = Training_1D_FEM_LBFGS(Model_FEM, config, Mat, Model_test)
            else:
                Model_FEM = Training_1D_FEM_LBFGS(Model_FEM, config, Mat)

            l2_loss, l2_loss_grad = Pplot.Normalized_error_1D(Model_FEM,config,Mat)

            
            loss_u[se,res, t] = l2_loss
            loss_grad[se,res, t] = l2_loss_grad
# Out:
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           10
# epoch =  1
#      loss =  -0.013471980208606526
#      loss_decrease =  1.0134719802086065
# epoch =  2
#      loss =  -0.013471980208606526
#      loss_decrease =  0.0
# epoch =  3
#      loss =  -0.013471980208606526
#      loss_decrease =  0.0
# epoch =  4
#      loss =  -0.013471980208606526
#      loss_decrease =  0.0
# epoch =  5
#      loss =  -0.013471980208606526
#      loss_decrease =  0.0
# epoch =  6
#      loss =  -0.013471980208606526
#      loss_decrease =  0.0
# * Final training loss: -1.3472e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           21
# epoch =  1
#      loss =  -0.02627700903967657
#      loss_decrease =  1.0262770090396767
# epoch =  2
#      loss =  -0.026388067897390267
#      loss_decrease =  0.004226464950634384
# epoch =  3
#      loss =  -0.026388067897390267
#      loss_decrease =  0.0
# epoch =  4
#      loss =  -0.026388067897390267
#      loss_decrease =  0.0
# epoch =  5
#      loss =  -0.026388067897390267
#      loss_decrease =  0.0
# epoch =  6
#      loss =  -0.026388067897390267
#      loss_decrease =  0.0
# epoch =  7
#      loss =  -0.026388067897390267
#      loss_decrease =  0.0
# * Final training loss: -2.6388e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           41
# epoch =  1
#      loss =  0.29382898522387124
#      loss_decrease =  0.7061710147761288
# epoch =  2
#      loss =  -0.029891531117842565
#      loss_decrease =  1.1017310497637525
# epoch =  3
#      loss =  -0.029929934800869508
#      loss_decrease =  0.0012847680125699494
# epoch =  4
#      loss =  -0.029929934800869508
#      loss_decrease =  0.0
# epoch =  5
#      loss =  -0.029929934800869508
#      loss_decrease =  0.0
# epoch =  6
#      loss =  -0.029929934800869508
#      loss_decrease =  0.0
# epoch =  7
#      loss =  -0.029929934800869508
#      loss_decrease =  0.0
# epoch =  8
#      loss =  -0.029929934800869508
#      loss_decrease =  0.0
# * Final training loss: -2.993e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           80
# epoch =  1
#      loss =  0.6227918382287847
#      loss_decrease =  0.3772081617712153
# epoch =  2
#      loss =  0.3087961605644351
#      loss_decrease =  0.504174361946282
# epoch =  3
#      loss =  -0.030197060299270793
#      loss_decrease =  1.097789623562919
# epoch =  4
#      loss =  -0.031032762354925338
#      loss_decrease =  0.027674947407868206
# epoch =  5
#      loss =  -0.031079868421427174
#      loss_decrease =  0.0015179462905389894
# epoch =  6
#      loss =  -0.031079868421427174
#      loss_decrease =  0.0
# epoch =  7
#      loss =  -0.031079868421427174
#      loss_decrease =  0.0
# epoch =  8
#      loss =  -0.031079868421427174
#      loss_decrease =  0.0
# epoch =  9
#      loss =  -0.031079868421427174
#      loss_decrease =  0.0
# epoch =  10
#      loss =  -0.031079868421427174
#      loss_decrease =  0.0
# * Final training loss: -3.108e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           160
# epoch =  1
#      loss =  1.2907607035749298
#      loss_decrease =  -0.2907607035749298
# epoch =  2
#      loss =  0.6493008386707397
#      loss_decrease =  0.4969626539819375
# epoch =  3
#      loss =  0.43675250071454674
#      loss_decrease =  0.327349550928235
# epoch =  4
#      loss =  0.31665659575837746
#      loss_decrease =  0.2749747391478858
# epoch =  5
#      loss =  -0.02840862835464342
#      loss_decrease =  1.0897143111344518
# epoch =  6
#      loss =  -0.030461244855087007
#      loss_decrease =  0.07225327723744479
# epoch =  7
#      loss =  -0.031050693362585598
#      loss_decrease =  0.019350768831108808
# epoch =  8
#      loss =  -0.031335084737076
#      loss_decrease =  0.00915893797183528
# epoch =  9
#      loss =  -0.03139747621127726
#      loss_decrease =  0.0019911059671538487
# epoch =  10
#      loss =  -0.03139778875499977
#      loss_decrease =  9.954421826891042e-06
# epoch =  11
#      loss =  -0.03139778875499977
#      loss_decrease =  0.0
# epoch =  12
#      loss =  -0.03139778875499977
#      loss_decrease =  0.0
# epoch =  13
#      loss =  -0.03139778875499977
#      loss_decrease =  0.0
# epoch =  14
#      loss =  -0.03139778875499977
#      loss_decrease =  0.0
# epoch =  15
#      loss =  -0.03139778875499977
#      loss_decrease =  0.0
# * Final training loss: -3.1398e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           324
# epoch =  1
#      loss =  2.748125204951953
#      loss_decrease =  -1.7481252049519531
# epoch =  2
#      loss =  1.3741057390125277
#      loss_decrease =  0.4999843032855732
# epoch =  3
#      loss =  0.8877273864466988
#      loss_decrease =  0.35395991644380626
# epoch =  4
#      loss =  0.6697213137739644
#      loss_decrease =  0.2455777257760922
# epoch =  5
#      loss =  0.5364211642044452
#      loss_decrease =  0.19903823699197504
# epoch =  6
#      loss =  0.4458210461350023
#      loss_decrease =  0.1688973592304286
# epoch =  7
#      loss =  0.3701548607757078
#      loss_decrease =  0.16972322418439945
# epoch =  8
#      loss =  0.3212889512175592
#      loss_decrease =  0.13201477202202272
# epoch =  9
#      loss =  0.255587519480813
#      loss_decrease =  0.20449328085439453
# epoch =  10
#      loss =  -0.02869372639370903
#      loss_decrease =  1.1122657571543242
# epoch =  11
#      loss =  -0.030112093947540778
#      loss_decrease =  0.04943127756814182
# epoch =  12
#      loss =  -0.03053912429043411
#      loss_decrease =  0.01418135662160448
# epoch =  13
#      loss =  -0.030893626515426625
#      loss_decrease =  0.011608133279170546
# epoch =  14
#      loss =  -0.031132129629552866
#      loss_decrease =  0.007720139751386747
# epoch =  15
#      loss =  -0.03128847383787874
#      loss_decrease =  0.0050219567432824574
# epoch =  16
#      loss =  -0.03142668136575316
#      loss_decrease =  0.004417202596411111
# epoch =  17
#      loss =  -0.03146601727816909
#      loss_decrease =  0.0012516724867677187
# epoch =  18
#      loss =  -0.03148188661627491
#      loss_decrease =  0.0005043325936525785
# epoch =  19
#      loss =  -0.031482391793317605
#      loss_decrease =  1.604659367639855e-05
# epoch =  20
#      loss =  -0.031482417795041136
#      loss_decrease =  8.259132184725471e-07
# epoch =  21
#      loss =  -0.03148242184216268
#      loss_decrease =  1.2855180227770824e-07
# epoch =  22
#      loss =  -0.031482422663853135
#      loss_decrease =  2.6099975913879346e-08
# epoch =  23
#      loss =  -0.03148242505551003
#      loss_decrease =  7.596800662070773e-08
# epoch =  24
#      loss =  -0.03148242640733571
#      loss_decrease =  4.293905811864617e-08
# epoch =  25
#      loss =  -0.03148242640733571
#      loss_decrease =  0.0
# epoch =  26
#      loss =  -0.03148242640733571
#      loss_decrease =  0.0
# * Final training loss: -3.1482e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           10
# epoch =  1
#      loss =  -0.019001305289668043
#      loss_decrease =  1.019001305289668
# epoch =  2
#      loss =  -0.021647487351436505
#      loss_decrease =  0.1392631727888359
# epoch =  3
#      loss =  -0.021925963637317906
#      loss_decrease =  0.01286413898114241
# epoch =  4
#      loss =  -0.021925968109557006
#      loss_decrease =  2.0397001353556984e-07
# epoch =  5
#      loss =  -0.021925968119468422
#      loss_decrease =  4.520400371311007e-10
# epoch =  6
#      loss =  -0.02192596812937983
#      loss_decrease =  4.520397204575462e-10
# epoch =  7
#      loss =  -0.021925968148211517
#      loss_decrease =  8.588759273614525e-10
# epoch =  8
#      loss =  -0.021925968167043182
#      loss_decrease =  8.588749772161429e-10
# epoch =  9
#      loss =  -0.02192596817695458
#      loss_decrease =  4.5203924477289417e-10
# * Final training loss: -2.1926e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           21
# epoch =  1
#      loss =  -0.026569854013489443
#      loss_decrease =  1.0265698540134895
# epoch =  2
#      loss =  -0.02667660282909461
#      loss_decrease =  0.004017666621388695
# epoch =  3
#      loss =  -0.02667662587332782
#      loss_decrease =  8.638368744618893e-07
# epoch =  4
#      loss =  -0.02667662650726251
#      loss_decrease =  2.3763675959030306e-08
# epoch =  5
#      loss =  -0.026676626512612843
#      loss_decrease =  2.0056251444183676e-10
# epoch =  6
#      loss =  -0.026676626512612975
#      loss_decrease =  4.942116054738151e-15
# epoch =  7
#      loss =  -0.026676626512613127
#      loss_decrease =  5.7224501686441466e-15
# epoch =  8
#      loss =  -0.02667662651261326
#      loss_decrease =  4.942116054738098e-15
# * Final training loss: -2.6677e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           41
# epoch =  1
#      loss =  0.3122033812961341
#      loss_decrease =  0.6877966187038659
# epoch =  2
#      loss =  -0.029893603772666134
#      loss_decrease =  1.0957504164386713
# epoch =  3
#      loss =  -0.030324860857345183
#      loss_decrease =  0.01442639997367526
# epoch =  4
#      loss =  -0.03032573192401167
#      loss_decrease =  2.872450662133298e-05
# epoch =  5
#      loss =  -0.030325770009961416
#      loss_decrease =  1.255895483086722e-06
# epoch =  6
#      loss =  -0.030325770009961416
#      loss_decrease =  0.0
# epoch =  7
#      loss =  -0.030325770009961416
#      loss_decrease =  0.0
# epoch =  8
#      loss =  -0.030325770009961416
#      loss_decrease =  0.0
# epoch =  9
#      loss =  -0.030325770009961416
#      loss_decrease =  0.0
# epoch =  10
#      loss =  -0.030325770009961416
#      loss_decrease =  0.0
# * Final training loss: -3.0326e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           80
# epoch =  1
#      loss =  0.686853213042079
#      loss_decrease =  0.313146786957921
# epoch =  2
#      loss =  0.3325802156876521
#      loss_decrease =  0.5157914247577712
# epoch =  3
#      loss =  -0.030143617946296865
#      loss_decrease =  1.090635631719617
# epoch =  4
#      loss =  -0.03125993703449835
#      loss_decrease =  0.03703334782806404
# epoch =  5
#      loss =  -0.031259939102444526
#      loss_decrease =  6.615324186763738e-08
# epoch =  6
#      loss =  -0.031259939185374695
#      loss_decrease =  2.652921664501272e-09
# epoch =  7
#      loss =  -0.03125993926830441
#      loss_decrease =  2.6529070071789342e-09
# epoch =  8
#      loss =  -0.031259939351233695
#      loss_decrease =  2.652893459726736e-09
# epoch =  9
#      loss =  -0.0312599394341625
#      loss_decrease =  2.6528779145086096e-09
# * Final training loss: -3.126e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           160
# epoch =  1
#      loss =  1.9332914851917353
#      loss_decrease =  -0.9332914851917353
# epoch =  2
#      loss =  0.8795092035897324
#      loss_decrease =  0.5450715992252423
# epoch =  3
#      loss =  0.5492707656108619
#      loss_decrease =  0.3754803663577328
# epoch =  4
#      loss =  0.3870399200564235
#      loss_decrease =  0.2953567815938941
# epoch =  5
#      loss =  0.2912235079278739
#      loss_decrease =  0.24756209156559691
# epoch =  6
#      loss =  -0.029786607770688648
#      loss_decrease =  1.1022809181258326
# epoch =  7
#      loss =  -0.030780834352886643
#      loss_decrease =  0.03337830846170939
# epoch =  8
#      loss =  -0.031237775812019662
#      loss_decrease =  0.014844999128172316
# epoch =  9
#      loss =  -0.031238869386702586
#      loss_decrease =  3.5008084106379075e-05
# epoch =  10
#      loss =  -0.031327765653040004
#      loss_decrease =  0.002845694101056656
# epoch =  11
#      loss =  -0.03132782691345344
#      loss_decrease =  1.955467048461994e-06
# epoch =  12
#      loss =  -0.03132782691345344
#      loss_decrease =  0.0
# epoch =  13
#      loss =  -0.03132782691345344
#      loss_decrease =  0.0
# epoch =  14
#      loss =  -0.03132782691345344
#      loss_decrease =  0.0
# epoch =  15
#      loss =  -0.03132782691345344
#      loss_decrease =  0.0
# epoch =  16
#      loss =  -0.03132782691345344
#      loss_decrease =  0.0
# * Final training loss: -3.1328e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           324
# epoch =  1
#      loss =  10.209207735189986
#      loss_decrease =  -9.209207735189986
# epoch =  2
#      loss =  10.208962003358424
#      loss_decrease =  2.406962792176893e-05
# epoch =  3
#      loss =  10.208931474647477
#      loss_decrease =  2.9903834432551284e-06
# epoch =  4
#      loss =  10.208930709374998
#      loss_decrease =  7.49610750328082e-08
# epoch =  5
#      loss =  10.208930693477622
#      loss_decrease =  1.5572028366853828e-09
# epoch =  6
#      loss =  10.208930677580252
#      loss_decrease =  1.5572023171094117e-09
# epoch =  7
#      loss =  10.208930661682892
#      loss_decrease =  1.5572012755325856e-09
# epoch =  8
#      loss =  10.208930645785522
#      loss_decrease =  1.5572023219591681e-09
# * Final training loss: 1.0209e+01
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           10
# epoch =  1
#      loss =  -0.013542667867031023
#      loss_decrease =  1.013542667867031
# epoch =  2
#      loss =  -0.013542667867031023
#      loss_decrease =  0.0
# epoch =  3
#      loss =  -0.013542667867031023
#      loss_decrease =  0.0
# epoch =  4
#      loss =  -0.013542667867031023
#      loss_decrease =  0.0
# epoch =  5
#      loss =  -0.013542667867031023
#      loss_decrease =  0.0
# epoch =  6
#      loss =  -0.013542667867031023
#      loss_decrease =  0.0
# * Final training loss: -1.3543e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           21
# epoch =  1
#      loss =  -0.026355735412569234
#      loss_decrease =  1.0263557354125692
# epoch =  2
#      loss =  -0.026462930467839308
#      loss_decrease =  0.004067238253535967
# epoch =  3
#      loss =  -0.026462930467839308
#      loss_decrease =  0.0
# epoch =  4
#      loss =  -0.026462930467839308
#      loss_decrease =  0.0
# epoch =  5
#      loss =  -0.026462930467839308
#      loss_decrease =  0.0
# epoch =  6
#      loss =  -0.026462930467839308
#      loss_decrease =  0.0
# epoch =  7
#      loss =  -0.026462930467839308
#      loss_decrease =  0.0
# * Final training loss: -2.6463e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           41
# epoch =  1
#      loss =  0.29171896271812936
#      loss_decrease =  0.7082810372818706
# epoch =  2
#      loss =  -0.029880743217750215
#      loss_decrease =  1.1024298967037744
# epoch =  3
#      loss =  -0.029969800286411302
#      loss_decrease =  0.0029804167858911964
# epoch =  4
#      loss =  -0.029969800286411302
#      loss_decrease =  0.0
# epoch =  5
#      loss =  -0.029969800286411302
#      loss_decrease =  0.0
# epoch =  6
#      loss =  -0.029969800286411302
#      loss_decrease =  0.0
# epoch =  7
#      loss =  -0.029969800286411302
#      loss_decrease =  0.0
# epoch =  8
#      loss =  -0.029969800286411302
#      loss_decrease =  0.0
# * Final training loss: -2.997e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           80
# epoch =  1
#      loss =  0.6254651974492133
#      loss_decrease =  0.37453480255078675
# epoch =  2
#      loss =  0.30261095817845546
#      loss_decrease =  0.5161825799219997
# epoch =  3
#      loss =  -0.03025965623373865
#      loss_decrease =  1.099995242789238
# epoch =  4
#      loss =  -0.031056634439869023
#      loss_decrease =  0.026337979518807803
# epoch =  5
#      loss =  -0.03110018601033482
#      loss_decrease =  0.0014023274334545885
# epoch =  6
#      loss =  -0.03110018601033482
#      loss_decrease =  0.0
# epoch =  7
#      loss =  -0.03110018601033482
#      loss_decrease =  0.0
# epoch =  8
#      loss =  -0.03110018601033482
#      loss_decrease =  0.0
# epoch =  9
#      loss =  -0.03110018601033482
#      loss_decrease =  0.0
# epoch =  10
#      loss =  -0.03110018601033482
#      loss_decrease =  0.0
# * Final training loss: -3.1100e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           160
# epoch =  1
#      loss =  1.2952913177425893
#      loss_decrease =  -0.2952913177425893
# epoch =  2
#      loss =  0.6452367921457118
#      loss_decrease =  0.501859710393011
# epoch =  3
#      loss =  0.43187725483058226
#      loss_decrease =  0.33066858541282196
# epoch =  4
#      loss =  0.31154121626751674
#      loss_decrease =  0.27863481398267015
# epoch =  5
#      loss =  -0.029137604847426727
#      loss_decrease =  1.093527287324983
# epoch =  6
#      loss =  -0.03055804880521625
#      loss_decrease =  0.048749509962380026
# epoch =  7
#      loss =  -0.031100733682158266
#      loss_decrease =  0.017759146874894088
# epoch =  8
#      loss =  -0.03136451147432381
#      loss_decrease =  0.008481400948970671
# epoch =  9
#      loss =  -0.03140777426583188
#      loss_decrease =  0.0013793548655615519
# epoch =  10
#      loss =  -0.031407813184170755
#      loss_decrease =  1.239130749876756e-06
# epoch =  11
#      loss =  -0.031407813184170755
#      loss_decrease =  0.0
# epoch =  12
#      loss =  -0.031407813184170755
#      loss_decrease =  0.0
# epoch =  13
#      loss =  -0.031407813184170755
#      loss_decrease =  0.0
# epoch =  14
#      loss =  -0.031407813184170755
#      loss_decrease =  0.0
# epoch =  15
#      loss =  -0.031407813184170755
#      loss_decrease =  0.0
# * Final training loss: -3.1408e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           324
# epoch =  1
#      loss =  2.757377207919668
#      loss_decrease =  -1.7573772079196681
# epoch =  2
#      loss =  1.3630908785062148
#      loss_decrease =  0.5056567253144836
# epoch =  3
#      loss =  0.877331897055613
#      loss_decrease =  0.3563658073795753
# epoch =  4
#      loss =  0.6652499444646427
#      loss_decrease =  0.24173514413727817
# epoch =  5
#      loss =  0.5315996887219891
#      loss_decrease =  0.20090231777502524
# epoch =  6
#      loss =  0.44113866004154734
#      loss_decrease =  0.1701675727047881
# epoch =  7
#      loss =  0.3680449412088551
#      loss_decrease =  0.16569329658345544
# epoch =  8
#      loss =  0.3197113385120625
#      loss_decrease =  0.13132527385932644
# epoch =  9
#      loss =  0.22965698923982908
#      loss_decrease =  0.2816739302751871
# epoch =  10
#      loss =  -0.02840435269349191
#      loss_decrease =  1.1236816383751747
# epoch =  11
#      loss =  -0.03007687914000228
#      loss_decrease =  0.05888275168803918
# epoch =  12
#      loss =  -0.030490012661777616
#      loss_decrease =  0.013735917209105192
# epoch =  13
#      loss =  -0.03089417523366276
#      loss_decrease =  0.013255572451493357
# epoch =  14
#      loss =  -0.031142836432327174
#      loss_decrease =  0.008048805212753196
# epoch =  15
#      loss =  -0.03129414592564791
#      loss_decrease =  0.004858564943162019
# epoch =  16
#      loss =  -0.03142296021862824
#      loss_decrease =  0.004116242484660984
# epoch =  17
#      loss =  -0.03146546406834663
#      loss_decrease =  0.0013526367160403595
# epoch =  18
#      loss =  -0.031485961007299154
#      loss_decrease =  0.0006514106675178846
# epoch =  19
#      loss =  -0.031487107450864665
#      loss_decrease =  3.6411261680893874e-05
# epoch =  20
#      loss =  -0.03148727096249311
#      loss_decrease =  5.192970764322199e-06
# epoch =  21
#      loss =  -0.03148731188852386
#      loss_decrease =  1.2997643015995994e-06
# epoch =  22
#      loss =  -0.03148731287481802
#      loss_decrease =  3.132354266850711e-08
# epoch =  23
#      loss =  -0.031487316177364964
#      loss_decrease =  1.0488500423583891e-07
# epoch =  24
#      loss =  -0.031487318187852845
#      loss_decrease =  6.385072227239339e-08
# epoch =  25
#      loss =  -0.03148735141913907
#      loss_decrease =  1.0553863629964552e-06
# epoch =  26
#      loss =  -0.03148735428238458
#      loss_decrease =  9.093319655785906e-08
# epoch =  27
#      loss =  -0.031487355009024505
#      loss_decrease =  2.3077198399317403e-08
# epoch =  28
#      loss =  -0.031487355009024505
#      loss_decrease =  0.0
# epoch =  29
#      loss =  -0.031487355009024505
#      loss_decrease =  0.0
# epoch =  30
#      loss =  -0.031487355009024505
#      loss_decrease =  0.0
# * Final training loss: -3.1487e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           10
# epoch =  1
#      loss =  -0.023207696731171346
#      loss_decrease =  1.0232076967311714
# epoch =  2
#      loss =  -0.02329207125347184
#      loss_decrease =  0.0036356267180605354
# epoch =  3
#      loss =  -0.023292151563880783
#      loss_decrease =  3.4479719759843043e-06
# epoch =  4
#      loss =  -0.023292152970388037
#      loss_decrease =  6.038545861927012e-08
# epoch =  5
#      loss =  -0.02329215299951285
#      loss_decrease =  1.2504131202008807e-09
# epoch =  6
#      loss =  -0.023292152999515554
#      loss_decrease =  1.1603475108670252e-13
# epoch =  7
#      loss =  -0.02329215299951826
#      loss_decrease =  1.1618370455406607e-13
# epoch =  8
#      loss =  -0.02329215299952094
#      loss_decrease =  1.1514103028241365e-13
# * Final training loss: -2.3292e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           21
# epoch =  1
#      loss =  -0.026397244158221565
#      loss_decrease =  1.0263972441582216
# epoch =  2
#      loss =  -0.026635327205663275
#      loss_decrease =  0.009019238751389056
# epoch =  3
#      loss =  -0.026635388774432004
#      loss_decrease =  2.3115454243812265e-06
# epoch =  4
#      loss =  -0.02663540553752404
#      loss_decrease =  6.293541340040147e-07
# epoch =  5
#      loss =  -0.026635411305630553
#      loss_decrease =  2.1655786337225603e-07
# epoch =  6
#      loss =  -0.026635411850715194
#      loss_decrease =  2.0464660161012955e-08
# epoch =  7
#      loss =  -0.026635411875143324
#      loss_decrease =  9.171297892777237e-10
# epoch =  8
#      loss =  -0.026635411875147355
#      loss_decrease =  1.513585514302623e-13
# epoch =  9
#      loss =  -0.026635411877593794
#      loss_decrease =  9.184911036008273e-11
# epoch =  10
#      loss =  -0.026635411877597815
#      loss_decrease =  1.5096778062954807e-13
# * Final training loss: -2.6635e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           41
# epoch =  1
#      loss =  0.30550768869803313
#      loss_decrease =  0.6944923113019669
# epoch =  2
#      loss =  -0.030090811977810293
#      loss_decrease =  1.0984944506832113
# epoch =  3
#      loss =  -0.03026462369813112
#      loss_decrease =  0.0057762389545685825
# epoch =  4
#      loss =  -0.030264640473316506
#      loss_decrease =  5.542836267828853e-07
# epoch =  5
#      loss =  -0.030264641563091436
#      loss_decrease =  3.600819018417023e-08
# epoch =  6
#      loss =  -0.030264641563425364
#      loss_decrease =  1.1033579549769557e-11
# epoch =  7
#      loss =  -0.030264641563425364
#      loss_decrease =  0.0
# epoch =  8
#      loss =  -0.030264641563425364
#      loss_decrease =  0.0
# epoch =  9
#      loss =  -0.030264641563425364
#      loss_decrease =  0.0
# * Final training loss: -3.0265e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           80
# epoch =  1
#      loss =  12.461084635114837
#      loss_decrease =  -11.461084635114837
# epoch =  2
#      loss =  0.6603159484370842
#      loss_decrease =  0.9470097533423102
# epoch =  3
#      loss =  0.3242398765142786
#      loss_decrease =  0.5089625242556555
# epoch =  4
#      loss =  -0.030010003501493892
#      loss_decrease =  1.092554943655033
# epoch =  5
#      loss =  -0.03108229666309553
#      loss_decrease =  0.035731190819363226
# epoch =  6
#      loss =  -0.03108230740819752
#      loss_decrease =  3.456984568632836e-07
# epoch =  7
#      loss =  -0.031082307408378456
#      loss_decrease =  5.821161396261522e-12
# epoch =  8
#      loss =  -0.03108230740855939
#      loss_decrease =  5.821161396227636e-12
# epoch =  9
#      loss =  -0.031082307408740344
#      loss_decrease =  5.821719502595947e-12
# epoch =  10
#      loss =  -0.031082307408921272
#      loss_decrease =  5.820938153598984e-12
# epoch =  11
#      loss =  -0.031082307409102217
#      loss_decrease =  5.8214962599672905e-12
# * Final training loss: -3.1082e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           160
# epoch =  1
#      loss =  1.6397814437475775
#      loss_decrease =  -0.6397814437475775
# epoch =  2
#      loss =  0.76329322654767
#      loss_decrease =  0.5345152675936924
# epoch =  3
#      loss =  0.49592376026862867
#      loss_decrease =  0.3502840808483753
# epoch =  4
#      loss =  0.34742498256485943
#      loss_decrease =  0.2994387234508212
# epoch =  5
#      loss =  0.028415802567933777
#      loss_decrease =  0.9182102497115936
# epoch =  6
#      loss =  -0.030156605152211417
#      loss_decrease =  2.061261777847587
# epoch =  7
#      loss =  -0.03089870142286307
#      loss_decrease =  0.02460808393073503
# epoch =  8
#      loss =  -0.031216924978509846
#      loss_decrease =  0.010298929760566228
# epoch =  9
#      loss =  -0.03121692501961922
#      loss_decrease =  1.316893732441298e-09
# epoch =  10
#      loss =  -0.0312169250607283
#      loss_decrease =  1.3168843949527255e-09
# epoch =  11
#      loss =  -0.03121692510183713
#      loss_decrease =  1.31687628000345e-09
# epoch =  12
#      loss =  -0.031216925142945683
#      loss_decrease =  1.3168674982146111e-09
# epoch =  13
#      loss =  -0.031216925184053956
#      loss_decrease =  1.316858494145942e-09
# * Final training loss: -3.1217e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           324
# epoch =  1
#      loss =  18.21127268090691
#      loss_decrease =  -17.21127268090691
# epoch =  2
#      loss =  4.8198151147226405
#      loss_decrease =  0.7353389189666113
# epoch =  3
#      loss =  2.2602514433437273
#      loss_decrease =  0.5310501773315852
# epoch =  4
#      loss =  1.4178653804378611
#      loss_decrease =  0.37269573055096616
# epoch =  5
#      loss =  0.9627592213139727
#      loss_decrease =  0.3209798090869133
# epoch =  6
#      loss =  0.7366923066573005
#      loss_decrease =  0.23481147690087706
# epoch =  7
#      loss =  0.5976279220110366
#      loss_decrease =  0.18876861260742706
# epoch =  8
#      loss =  0.4974007114106409
#      loss_decrease =  0.167708379928314
# epoch =  9
#      loss =  0.4229141158160328
#      loss_decrease =  0.14975168689116322
# epoch =  10
#      loss =  0.360695349025686
#      loss_decrease =  0.14711915366147738
# epoch =  11
#      loss =  0.316936688698395
#      loss_decrease =  0.12131750643719798
# epoch =  12
#      loss =  0.2532385680322451
#      loss_decrease =  0.20098058362301702
# epoch =  13
#      loss =  -0.026416404058172638
#      loss_decrease =  1.1043143003983857
# epoch =  14
#      loss =  -0.02962433119873981
#      loss_decrease =  0.12143693492508915
# epoch =  15
#      loss =  -0.030241632998586856
#      loss_decrease =  0.02083766197811434
# epoch =  16
#      loss =  -0.030561744793231687
#      loss_decrease =  0.010585135884024146
# epoch =  17
#      loss =  -0.030900047719183178
#      loss_decrease =  0.01106948992082458
# epoch =  18
#      loss =  -0.031039504277035293
#      loss_decrease =  0.004513150242338889
# epoch =  19
#      loss =  -0.031220010271528667
#      loss_decrease =  0.005815363315158423
# epoch =  20
#      loss =  -0.03128783029551027
#      loss_decrease =  0.0021723254858584586
# epoch =  21
#      loss =  -0.03128783912167377
#      loss_decrease =  2.8209573556522604e-07
# epoch =  22
#      loss =  -0.0312878391935695
#      loss_decrease =  2.297880822148484e-09
# epoch =  23
#      loss =  -0.03128783919382824
#      loss_decrease =  8.269807741660077e-12
# epoch =  24
#      loss =  -0.03128783919408703
#      loss_decrease =  8.271138397990346e-12
# epoch =  25
#      loss =  -0.0312878391943458
#      loss_decrease =  8.270694845789051e-12
# epoch =  26
#      loss =  -0.03128783919460455
#      loss_decrease =  8.27002951752133e-12
# * Final training loss: -3.1288e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           10
# epoch =  1
#      loss =  -0.013568297011566408
#      loss_decrease =  1.0135682970115665
# epoch =  2
#      loss =  -0.013568297011566408
#      loss_decrease =  0.0
# epoch =  3
#      loss =  -0.013568297011566408
#      loss_decrease =  0.0
# epoch =  4
#      loss =  -0.013568297011566408
#      loss_decrease =  0.0
# epoch =  5
#      loss =  -0.013568297011566408
#      loss_decrease =  0.0
# epoch =  6
#      loss =  -0.013568297011566408
#      loss_decrease =  0.0
# * Final training loss: -1.3568e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           21
# epoch =  1
#      loss =  -0.026380535548403732
#      loss_decrease =  1.0263805355484037
# epoch =  2
#      loss =  -0.026486618557287907
#      loss_decrease =  0.0040212606256431185
# epoch =  3
#      loss =  -0.026486618557287907
#      loss_decrease =  0.0
# epoch =  4
#      loss =  -0.026486618557287907
#      loss_decrease =  0.0
# epoch =  5
#      loss =  -0.026486618557287907
#      loss_decrease =  0.0
# epoch =  6
#      loss =  -0.026486618557287907
#      loss_decrease =  0.0
# epoch =  7
#      loss =  -0.026486618557287907
#      loss_decrease =  0.0
# * Final training loss: -2.6487e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           41
# epoch =  1
#      loss =  0.2910529441370025
#      loss_decrease =  0.7089470558629976
# epoch =  2
#      loss =  -0.029930544914160376
#      loss_decrease =  1.1028353965046018
# epoch =  3
#      loss =  -0.02998274060732807
#      loss_decrease =  0.0017438938488219971
# epoch =  4
#      loss =  -0.02998274060732807
#      loss_decrease =  0.0
# epoch =  5
#      loss =  -0.02998274060732807
#      loss_decrease =  0.0
# epoch =  6
#      loss =  -0.02998274060732807
#      loss_decrease =  0.0
# epoch =  7
#      loss =  -0.02998274060732807
#      loss_decrease =  0.0
# epoch =  8
#      loss =  -0.02998274060732807
#      loss_decrease =  0.0
# * Final training loss: -2.9983e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           80
# epoch =  1
#      loss =  0.6264896111198315
#      loss_decrease =  0.3735103888801685
# epoch =  2
#      loss =  0.3088025677267282
#      loss_decrease =  0.5070906807620436
# epoch =  3
#      loss =  -0.030126534280366782
#      loss_decrease =  1.0975592091158612
# epoch =  4
#      loss =  -0.031043465185337654
#      loss_decrease =  0.03043599029472264
# epoch =  5
#      loss =  -0.031106867002076585
#      loss_decrease =  0.0020423563014117644
# epoch =  6
#      loss =  -0.031106867002076585
#      loss_decrease =  0.0
# epoch =  7
#      loss =  -0.031106867002076585
#      loss_decrease =  0.0
# epoch =  8
#      loss =  -0.031106867002076585
#      loss_decrease =  0.0
# epoch =  9
#      loss =  -0.031106867002076585
#      loss_decrease =  0.0
# epoch =  10
#      loss =  -0.031106867002076585
#      loss_decrease =  0.0
# * Final training loss: -3.1107e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           160
# epoch =  1
#      loss =  1.2967669946222269
#      loss_decrease =  -0.2967669946222269
# epoch =  2
#      loss =  0.6389788552998176
#      loss_decrease =  0.5072523761402762
# epoch =  3
#      loss =  0.4252552593136222
#      loss_decrease =  0.3344767893546546
# epoch =  4
#      loss =  0.31235085916061006
#      loss_decrease =  0.265497951360423
# epoch =  5
#      loss =  -0.028549306431760166
#      loss_decrease =  1.0914014019634253
# epoch =  6
#      loss =  -0.030511792627392235
#      loss_decrease =  0.06874024068931033
# epoch =  7
#      loss =  -0.031095304423172355
#      loss_decrease =  0.01912414006302166
# epoch =  8
#      loss =  -0.031361073173468854
#      loss_decrease =  0.008546909420138884
# epoch =  9
#      loss =  -0.03141092647881272
#      loss_decrease =  0.001589655592080923
# epoch =  10
#      loss =  -0.03141113348501013
#      loss_decrease =  6.590260798335146e-06
# epoch =  11
#      loss =  -0.03141113348501013
#      loss_decrease =  0.0
# epoch =  12
#      loss =  -0.03141113348501013
#      loss_decrease =  0.0
# epoch =  13
#      loss =  -0.03141113348501013
#      loss_decrease =  0.0
# epoch =  14
#      loss =  -0.03141113348501013
#      loss_decrease =  0.0
# epoch =  15
#      loss =  -0.03141113348501013
#      loss_decrease =  0.0
# * Final training loss: -3.1411e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           324
# epoch =  1
#      loss =  2.7604525557468143
#      loss_decrease =  -1.7604525557468143
# epoch =  2
#      loss =  1.3520191857828987
#      loss_decrease =  0.5102182854154786
# epoch =  3
#      loss =  0.884426070192869
#      loss_decrease =  0.3458479883325515
# epoch =  4
#      loss =  0.6662344222427097
#      loss_decrease =  0.24670422469859773
# epoch =  5
#      loss =  0.5358717156838306
#      loss_decrease =  0.1956709263385791
# epoch =  6
#      loss =  0.4444193132295925
#      loss_decrease =  0.17066099922354536
# epoch =  7
#      loss =  0.3685250110684442
#      loss_decrease =  0.17077183619592237
# epoch =  8
#      loss =  0.32008662160223494
#      loss_decrease =  0.13143854015708328
# epoch =  9
#      loss =  0.2326409408522364
#      loss_decrease =  0.2731938008289065
# epoch =  10
#      loss =  -0.028008159033090584
#      loss_decrease =  1.1203922187147624
# epoch =  11
#      loss =  -0.030052810599864806
#      loss_decrease =  0.07300199789491855
# epoch =  12
#      loss =  -0.030448519244176332
#      loss_decrease =  0.01316710937889137
# epoch =  13
#      loss =  -0.030849224521335865
#      loss_decrease =  0.013160090773089815
# epoch =  14
#      loss =  -0.03111638633617307
#      loss_decrease =  0.008660244106053061
# epoch =  15
#      loss =  -0.031286896081136495
#      loss_decrease =  0.005479741224488027
# epoch =  16
#      loss =  -0.03139947848670767
#      loss_decrease =  0.0035983884524438984
# epoch =  17
#      loss =  -0.031462206571107244
#      loss_decrease =  0.0019977428741732215
# epoch =  18
#      loss =  -0.031484913168553216
#      loss_decrease =  0.0007217102651288348
# epoch =  19
#      loss =  -0.031488659577744715
#      loss_decrease =  0.00011899061532877013
# epoch =  20
#      loss =  -0.03148894959538376
#      loss_decrease =  9.210224980424147e-06
# epoch =  21
#      loss =  -0.03148896913825397
#      loss_decrease =  6.206262978636429e-07
# epoch =  22
#      loss =  -0.0314889727799629
#      loss_decrease =  1.1565030634956136e-07
# epoch =  23
#      loss =  -0.0314889727799629
#      loss_decrease =  0.0
# epoch =  24
#      loss =  -0.0314889727799629
#      loss_decrease =  0.0
# epoch =  25
#      loss =  -0.0314889727799629
#      loss_decrease =  0.0
# epoch =  26
#      loss =  -0.0314889727799629
#      loss_decrease =  0.0
# epoch =  27
#      loss =  -0.0314889727799629
#      loss_decrease =  0.0
# * Final training loss: -3.1489e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           10
# epoch =  1
#      loss =  -0.022788103024303584
#      loss_decrease =  1.0227881030243036
# epoch =  2
#      loss =  -0.02278816944643649
#      loss_decrease =  2.9147723631991576e-06
# epoch =  3
#      loss =  -0.022788175876573898
#      loss_decrease =  2.8216998402419945e-07
# epoch =  4
#      loss =  -0.022788175952015627
#      loss_decrease =  3.3105646393623932e-09
# epoch =  5
#      loss =  -0.022788175952445644
#      loss_decrease =  1.8870186623028223e-11
# epoch =  6
#      loss =  -0.022788175952445644
#      loss_decrease =  0.0
# epoch =  7
#      loss =  -0.022788175952445644
#      loss_decrease =  0.0
# epoch =  8
#      loss =  -0.022788175952445644
#      loss_decrease =  0.0
# * Final training loss: -2.2788e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           21
# epoch =  1
#      loss =  -0.026472253484031656
#      loss_decrease =  1.0264722534840316
# epoch =  2
#      loss =  -0.026570734051182193
#      loss_decrease =  0.0037201429492937153
# epoch =  3
#      loss =  -0.026570737138815068
#      loss_decrease =  1.16204274564754e-07
# epoch =  4
#      loss =  -0.026570738701584645
#      loss_decrease =  5.881543928480381e-08
# epoch =  5
#      loss =  -0.026570738701584645
#      loss_decrease =  0.0
# epoch =  6
#      loss =  -0.026570738701584645
#      loss_decrease =  0.0
# epoch =  7
#      loss =  -0.026570738701584645
#      loss_decrease =  0.0
# epoch =  8
#      loss =  -0.026570738701584645
#      loss_decrease =  0.0
# * Final training loss: -2.6571e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           41
# epoch =  1
#      loss =  0.3169546257414475
#      loss_decrease =  0.6830453742585525
# epoch =  2
#      loss =  -0.030038206742051574
#      loss_decrease =  1.0947713152057132
# epoch =  3
#      loss =  -0.03027458124062936
#      loss_decrease =  0.00786912816093229
# epoch =  4
#      loss =  -0.030275053953107974
#      loss_decrease =  1.5614170675340915e-05
# epoch =  5
#      loss =  -0.030275105464998835
#      loss_decrease =  1.7014632225018612e-06
# epoch =  6
#      loss =  -0.030275105464998835
#      loss_decrease =  0.0
# epoch =  7
#      loss =  -0.030275105464998835
#      loss_decrease =  0.0
# epoch =  8
#      loss =  -0.030275105464998835
#      loss_decrease =  0.0
# epoch =  9
#      loss =  -0.030275105464998835
#      loss_decrease =  0.0
# epoch =  10
#      loss =  -0.030275105464998835
#      loss_decrease =  0.0
# * Final training loss: -3.0275e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           80
# epoch =  1
#      loss =  12.692851873214762
#      loss_decrease =  -11.692851873214762
# epoch =  2
#      loss =  0.6735531310715126
#      loss_decrease =  0.9469344527298167
# epoch =  3
#      loss =  0.3189497531840202
#      loss_decrease =  0.5264668242628114
# epoch =  4
#      loss =  -0.029963942455490073
#      loss_decrease =  1.0939456518036625
# epoch =  5
#      loss =  -0.03065983583056571
#      loss_decrease =  0.023224359615205886
# epoch =  6
#      loss =  -0.031128556610325382
#      loss_decrease =  0.015287778523992962
# epoch =  7
#      loss =  -0.031128564005624484
#      loss_decrease =  2.375728240419306e-07
# epoch =  8
#      loss =  -0.031128564628444245
#      loss_decrease =  2.0007982409017288e-08
# epoch =  9
#      loss =  -0.031128564632170903
#      loss_decrease =  1.1971826891685046e-10
# epoch =  10
#      loss =  -0.031128564632170903
#      loss_decrease =  0.0
# epoch =  11
#      loss =  -0.031128564632170903
#      loss_decrease =  0.0
# epoch =  12
#      loss =  -0.031128564632170903
#      loss_decrease =  0.0
# * Final training loss: -3.1129e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           160
# epoch =  1
#      loss =  1.574979297447743
#      loss_decrease =  -0.574979297447743
# epoch =  2
#      loss =  0.7197839659749168
#      loss_decrease =  0.5429883001374506
# epoch =  3
#      loss =  0.47436439959772386
#      loss_decrease =  0.3409628138142568
# epoch =  4
#      loss =  0.3366524769471267
#      loss_decrease =  0.29030830046981027
# epoch =  5
#      loss =  -0.02570455218348173
#      loss_decrease =  1.0763533731181154
# epoch =  6
#      loss =  -0.030227142798529005
#      loss_decrease =  0.17594512375724586
# epoch =  7
#      loss =  -0.0309282428503163
#      loss_decrease =  0.023194387126176382
# epoch =  8
#      loss =  -0.03129076652782079
#      loss_decrease =  0.011721444352949476
# epoch =  9
#      loss =  -0.03141406992651365
#      loss_decrease =  0.003940568173145645
# epoch =  10
#      loss =  -0.03141478172778149
#      loss_decrease =  2.2658677131055215e-05
# epoch =  11
#      loss =  -0.03141478172779091
#      loss_decrease =  2.997340267774342e-13
# epoch =  12
#      loss =  -0.03141478172780032
#      loss_decrease =  2.997340267773444e-13
# epoch =  13
#      loss =  -0.031414781727809725
#      loss_decrease =  2.9929226697360346e-13
# epoch =  14
#      loss =  -0.03141478172781913
#      loss_decrease =  2.992922669735139e-13
# epoch =  15
#      loss =  -0.03141478172782852
#      loss_decrease =  2.990713870715989e-13
# * Final training loss: -3.1415e-02
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   v2.0.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 1D
#  * Elements type:            2-node bar
#  * Number of Dofs:           324
# epoch =  1
#      loss =  4.941238997370243
#      loss_decrease =  -3.9412389973702426
# epoch =  2
#      loss =  2.599632072049141
#      loss_decrease =  0.47389064292727373
# epoch =  3
#      loss =  1.5387323591233886
#      loss_decrease =  0.4080961011107645
# epoch =  4
#      loss =  1.0646067292372865
#      loss_decrease =  0.3081274186995132
# epoch =  5
#      loss =  0.7881704596506809
#      loss_decrease =  0.2596604567628951
# epoch =  6
#      loss =  0.6207021607617274
#      loss_decrease =  0.21247725899696357
# epoch =  7
#      loss =  0.5260553108690114
#      loss_decrease =  0.1524835192720533
# epoch =  8
#      loss =  0.4507281405374225
#      loss_decrease =  0.14319249093247052
# epoch =  9
#      loss =  0.3847615546110092
#      loss_decrease =  0.14635559663028475
# epoch =  10
#      loss =  0.33517579441289946
#      loss_decrease =  0.1288739989842294
# epoch =  11
#      loss =  0.29895974346056753
#      loss_decrease =  0.10805091404577316
# epoch =  12
#      loss =  0.12350619030703427
#      loss_decrease =  0.5868801970546091
# epoch =  13
#      loss =  0.12350227284253182
#      loss_decrease =  3.1718770473914687e-05
# Correction
# epoch =  14
#      loss =  0.10099912273470778
#      loss_decrease =  0.18220838847651058
# epoch =  15
#      loss =  0.10099481659231717
#      loss_decrease =  4.263544349706514e-05
# epoch =  16
#      loss =  0.10099478662825993
#      loss_decrease =  2.9668906035432576e-07
# epoch =  17
#      loss =  0.10099478662825993
#      loss_decrease =  0.0
# epoch =  18
#      loss =  0.10099478662825993
#      loss_decrease =  0.0
# epoch =  19
#      loss =  0.10099478662825993
#      loss_decrease =  0.0
# epoch =  20
#      loss =  0.10099478662825993
#      loss_decrease =  0.0
# epoch =  21
#      loss =  0.10099478662825993
#      loss_decrease =  0.0
# * Final training loss: 1.0099e-01

# %%
import matplotlib.pyplot as plt
import matplotlib

# Plot normalized displacement error

fig = matplotlib.pyplot.gcf()
ax = plt.gca()

plt.plot(mesh_resolution, loss_u[0,:,0],'-', color = "blue", label = '10 p./e.')
plt.plot(mesh_resolution, loss_u[0,:,1],'-', color = "gold", label = '20 p./e.')
plt.plot(mesh_resolution, loss_u[0,:,2],'-', color = "green", label = '30 p./e.')

plt.plot(mesh_resolution, loss_u[1,:,0],':', color = "blue", label = '10 p./e.,  r-adaptivity')
plt.plot(mesh_resolution, loss_u[1,:,1],':', color = "gold", label = '20 p./e.,  r-adaptivity')
plt.plot(mesh_resolution, loss_u[1,:,2],':', color = "green", label = '30 p./e.,  r-adaptivity')

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_ylim([0.00008, 29])

plt.xlabel("Number of mesh nodes")
plt.ylabel("Normalized displacement error")
plt.legend(loc="lower left", frameon=False )
plt.show()

# Plot normalized strain error

fig = matplotlib.pyplot.gcf()
ax = plt.gca()

plt.plot(mesh_resolution, loss_grad[0,:,0],'-', color = "blue", label = '10 p./e.')
plt.plot(mesh_resolution, loss_grad[0,:,1],'-', color = "gold", label = '20 p./e.')
plt.plot(mesh_resolution, loss_grad[0,:,2],'-', color = "green", label = '30 p./e.')

plt.plot(mesh_resolution, loss_grad[1,:,0],':', color = "blue", label = '10 p./e.,  r-adaptivity')
plt.plot(mesh_resolution, loss_grad[1,:,1],':', color = "gold", label = '20 p./e.,  r-adaptivity')
plt.plot(mesh_resolution, loss_grad[1,:,2],':', color = "green", label = '30 p./e.,  r-adaptivity')

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_ylim([0.01, 23])

plt.xlabel("Number of mesh nodes")
plt.ylabel("Normalized strain error")
plt.legend(loc="lower left", frameon=False )
plt.show()

# %%
loss_grad.shape
# Out:
# (2, 6, 3)
